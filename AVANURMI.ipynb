# %% [markdown]
# <a href="https://colab.research.google.com/github/NitinKumar314/AVANURMI/blob/main/AVANURMI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from glob import glob
import librosa
import librosa.display
import IPython.display as ipd
import os

# %%
df=glob("/content/audiodataset_circada/*.wav")
r_data,y= librosa.load(df[0])
pd.Series(r_data[100000:110000]).plot(figsize=(10,5))
r=librosa.stft(r_data)
# Out:
# <Axes: >
